# %% [markdown]
# ## Implementing SVM From Scratch

# %%
import pandas as pd
df = pd.read_csv('User_Data.csv')
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.shape
# Out:
# (400, 5)

# %%
for column in df.columns:
  bool_series = pd.isnull(df[column])
  print()
  print(bool_series)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: User ID, Length: 400, dtype: bool
#
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: Gender, Length: 400, dtype: bool
#
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: Age, Length: 400, dtype: bool
#
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: EstimatedSalary, Length: 400, dtype: bool
#
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: Purchased, Length: 400, dtype: bool

# %%
df = df.drop('User ID', axis=True)

# %%
normalized_df=(df['Age']-df['Age'].min())/(df['Age'].max()-df['Age'].min())

# %%
normalized_df
# Out:
# 0      0.023810
# 1      0.404762
# 2      0.190476
# 3      0.214286
# 4      0.023810
#          ...
# 395    0.666667
# 396    0.785714
# 397    0.761905
# 398    0.428571
# 399    0.738095
# Name: Age, Length: 400, dtype: float64

# %%
df = df.drop('Age', axis=True)

# %%
df = df.drop('EstimatedSalary', axis=True)

# %%
df.head()
# Out:
#    Gender  Purchased
# 0    Male          0
# 1    Male          0
# 2  Female          0
# 3  Female          0
# 4    Male          0

# %%
df['Age'] = normalized_df

# %%
df
# Out:
#      Gender  Purchased       Age
# 0      Male          0  0.023810
# 1      Male          0  0.404762
# 2    Female          0  0.190476
# 3    Female          0  0.214286
# 4      Male          0  0.023810
# ..      ...        ...       ...
# 395  Female          1  0.666667
# 396    Male          1  0.785714
# 397  Female          1  0.761905
# 398    Male          0  0.428571
# 399  Female          1  0.738095
#
# [400 rows x 3 columns]

# %%
for i in range(len(df)):
    if df.loc[i, "Gender"]=='Female':
      df.loc[i, "Gender"] = 1
    else:
      df.loc[i, "Gender"] = 0

# %%
df.head()
# Out:
#   Gender  Purchased       Age
# 0      0          0  0.023810
# 1      0          0  0.404762
# 2      1          0  0.190476
# 3      1          0  0.214286
# 4      0          0  0.023810

# %%
x_points = []
for i in range(len(df)):
  temp = []
  temp.append(df.loc[i, "Gender"])
  temp.append(df.loc[i, "Age"])
  x_points.append(temp)

# %%
y_points = []
for i in range(len(df)):
  temp = []
  temp.append(df.loc[i, "Purchased"])
  y_points.append(temp)

# %%
x1 = []
for i in x_points:
  x1.append(i[0])
x2 = []
for i in x_points:
  x2.append(i[1])

# %%
import numpy as np
from matplotlib import pyplot as plt

# Scatter plot
plt.scatter(x1, x2, cmap='hot')

# Display the plot
plt.show()
# Out:
# <ipython-input-37-0ff2ed2e4a01>:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x1, x2, cmap='hot')
